# %%
import pydicom
import IPython
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from rt_utils import RTStructBuilder
# from dicom_parser import Image
# import nifti

# %% [markdown]
# # LIDC-IDRI

# %%
#take an abitrary dicom from LIDC/IDRI
path_to_serie1 = "/media/christophe/Extreme SSD/CancerDatasets/HealthyCopy/LIDC-IDRI/LIDC-IDRI/LIDC-IDRI-0068/01-01-2000-NA-CT CHEST W CONT-80168/4.000000-Recon 3 CT CHEST-26125"

# print(os.listdir(path_to_serie))
path_to_dicom1 = os.path.join(path_to_serie1, '1-071.dcm')

#load a dicom
ds1 = pydicom.dcmread(path_to_dicom1)

print(ds1)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.6279.6001.516906022434550216616965144297
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0013) Implementation Version Name         SH: '0.5'
# (0002, 0016) Source Application Entity Title     AE: 'POSDA'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# ...

# %%
#show the image dicom
plt.imshow(ds1.pixel_array, cmap=plt.cm.gray)

# %%
#take an abitrary numpy from LIDC/IDRI preprocessed
path_to_folder = "/home/christophe/Desktop/bachelor/code/dataset_processing/LIDC-IDRI/output/True"

# print(os.listdir(path_to_serie))
path_to_numpy = os.path.join(path_to_folder, os.listdir(path_to_folder)[0])

#load a numpy
npy = np.load(path_to_numpy)

plt.imshow(npy, cmap=plt.cm.gray)

# %%
#take an abitrary numpy from LIDC/IDRI augmented
path_to_folder = "/home/christophe/Desktop/bachelor/code/dataset_processing/LIDC-IDRI/final/train/1"

# print(os.listdir(path_to_serie))
path_to_numpy = os.path.join(path_to_folder, os.listdir(path_to_folder)[2])

#load a numpy
npy = np.load(path_to_numpy)

plt.imshow(npy, cmap=plt.cm.gray)

# %% [markdown]
# # Head-neck PET-CT scans

# %%
#take an abitrary dicom from Head-neck PET-CT scans
path_to_serie2 = "/media/christophe/Extreme SSD/CancerDatasets/HealthyCopy/Head-Neck-PET-CT/Head-Neck-PET-CT/HN-HGJ-087/08-27-1885-NA-HEADNECK-74396/2.000000-2.5mm-13667"

# print(os.listdir(path_to_serie))
path_to_dicom2 = os.path.join(path_to_serie2, '1-080.dcm')

#load a dicom
ds2 = pydicom.dcmread(path_to_dicom2)

print(ds2)
# print(ds2[0x8,0x60].value)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 194
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.5168.2407.294519386082027480360036522298
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008, 0012) Instance Creation Date              DA: '18850827'
# (0008, 0013) Instance Creation Time              TM: '111111'
# ...

# %%
#show the image dicom
plt.imshow(ds2.pixel_array, cmap=plt.cm.gray)

# %% [markdown]
# ## RT struct

# %%
#take an abitrary dicom from Head-neck PET-CT scans
path_to_serie6 = "/media/christophe/Extreme SSD/CancerDatasets/HealthyCopy/Head-Neck-PET-CT/Head-Neck-PET-CT/HN-CHUM-001/08-27-1885-NA-TomoTherapy Patient Disease-00441/114120634.000000-TomoTherapy Structure Set-68567"

# print(os.listdir(path_to_serie))
path_to_dicom6 = os.path.join(path_to_serie6, '1-1.dcm')

#load a dicom
ds6 = pydicom.dcmread(path_to_dicom6)
print(ds6)

# Modality
# print(ds6[0x8,0x60].value)

# Referenced series
# print(ds6[0x3006, 0x10][0][0x3006,0x12][0][0x3006, 0x14][0][0x20,0xe].value)

# ROI number
# print(ds6[0x3006,0x20][0]['ROINumber'].value)

# plt.imshow(ds6.pixel_array, cmap=plt.cm.gray)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 198
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: RT Structure Set Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.14519.5.2.1.5168.2407.983984022391396112493624051082
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0012) Instance Creation Date              DA: '18850827'
# (0008, 0013) Instance Creation Time              TM: '111111'
# (0008, 0016) SOP Class UID                       UI: RT Structure Set Storage
# ...

# %%
# dicom-parser library
# image = Image(path_to_dicom6)
# print(image.header[0x3006,0x20][0]['ROINumber'])
# Out:
# 1
# /home/christophe/.local/lib/python3.8/site-packages/dicom_parser/image.py:57: UserWarning: Failed to read image data with the following exception:
# Unable to convert the pixel data: one of Pixel Data, Float Pixel Data or Double Float Pixel Data must be present in the dataset
#   warnings.warn(warning)

# %%
# Load existing RT Struct. Requires the series path and existing RT Struct path
rtstruct = RTStructBuilder.create_from(
  dicom_series_path="/media/christophe/Extreme SSD/CancerDatasets/HealthyCopy/Head-Neck-PET-CT/Head-Neck-PET-CT/HN-CHUS-057/08-27-1885-NA-R-ONCO POSITION DE TX FDG TE-93057/339020.000000-LOR-RAMLA-16691", 
  rt_struct_path="/media/christophe/Extreme SSD/CancerDatasets/HealthyCopy/Head-Neck-PET-CT/Head-Neck-PET-CT/HN-CHUS-057/08-27-1885-NA-R-ONCO POSITION DE TX FDG TE-93057/1.000000-RTstructCTsim-PETPET-CT-06489/1-1.dcm"
)

# View all of the ROI names from within the image
print(rtstruct.get_roi_names())

# Loading the 3D Mask from within the RT Struct
mask_3d = rtstruct.get_roi_mask_by_name("GTV T et N >1 cm")

# Display one slice of the region
first_mask_slice = mask_3d[:, :, 150]
plt.imshow(first_mask_slice)
plt.show()
# Out:
# ['Isocentre', 'GTV T et N >1 cm', 'GTV GG < 1cm', 'MARQUEURS', 'PATCH', 'ARTEFACTS', 'EXTERNE', 'PEAU', 'TISSUS SAINS', 'COU SAIN', 'CERVEAU', 'CERVEAU-', 'TRONC', 'PRV TRONC', 'MOELLE', 'PRV MOELLE', 'OEIL D', 'OEIL G', 'CRISTAL D', 'CRISTAL G', 'NOD', 'NOG', 'RAR OREILLE D', 'RAR- OR D', 'RAR OREILLE G', 'RAR- OR G', 'PAROTIDE D', 'PAR- D', 'PAROTIDE G', 'PAR- G', 'RAR CAV BUCC', 'RAR- CB', 'MANDIBULES', 'MAND-', 'MENTON', 'RAR LARYNX', 'RAR- LR', 'LARYNX', 'LR-', 'CTV 70', 'CTV 63', 'PTV 70', 'PTV 63', 'CTV 56', 'PTV 56', 'Metal', 'Dents', 'PTV1', 'PTV2', 'PTV3', 'CONF_I PTV1', 'CONF_E PTV1', 'CONF PTV1', 'CONF_I PTV2', 'CONF_E PTV2', 'CONF PTV2', 'CONF_I PTV3', 'CONF_E PTV3', 'CONF PTV3', 'tr_Tronc_Moelle', 'PTV1 XTR', 'PTV1 TR2', 'PTV1 TR3', 'PTV1-', 'PTV2 XTR', 'PTV2 TR3', 'PTV2-', 'f1-PTV1', 'f2_PTV1', 'f3-PTV1', '1f1-PTV1', '1f2_PTV1', '1f3-PTV1', 'f1-PTV3', 'c1tronc', 'c1-PTV1', '1f4-PTV1', '1f5-PTV1', '1f6-PTV1', 'f2-PTV3']

# %% [markdown]
# # BUSI

# %%
#take an abitrary dicom from BUSI
path_to_serie3 = "/media/christophe/Extreme SSD/CancerDatasets/HealthyCopy/BUSI/malignant"

# print(os.listdir(path_to_serie))
path_to_dicom3 = os.path.join(path_to_serie3, "malignant (5).png")

#load a dicom
ds3 = mpimg.imread(path_to_dicom3)

print(ds3)

# %%
#show the image jpg
plt.imshow(ds3, cmap=plt.cm.gray)
